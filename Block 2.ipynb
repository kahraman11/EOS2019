# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
files = [ "./data/cmds_sequence_2016-07-01.csv", "./data/cmds_sequence_2016-07-02.csv", "./data/cmds_sequence_2016-07-03.csv", "./data/cmds_sequence_2016-07-04.csv", 
    "./data/cmds_sequence_2016-07-05.csv", "./data/cmds_sequence_2016-07-06.csv", "./data/cmds_sequence_2016-07-07.csv", "./data/cmds_sequence_2016-07-08.csv", 
    "./data/cmds_sequence_2016-07-09.csv", "./data/cmds_sequence_2016-07-10.csv", "./data/cmds_sequence_2016-07-11.csv", "./data/cmds_sequence_2016-07-12.csv", 
    "./data/cmds_sequence_2016-07-13.csv", "./data/cmds_sequence_2016-07-14.csv", "./data/cmds_sequence_2016-07-15.csv", "./data/cmds_sequence_2016-07-16.csv", 
    "./data/cmds_sequence_2016-07-17.csv", "./data/cmds_sequence_2016-07-18.csv", "./data/cmds_sequence_2016-07-19.csv", "./data/cmds_sequence_2016-07-20.csv", 
    "./data/cmds_sequence_2016-07-21.csv", "./data/cmds_sequence_2016-07-22.csv", "./data/cmds_sequence_2016-07-23.csv", "./data/cmds_sequence_2016-07-24.csv", 
    "./data/cmds_sequence_2016-07-25.csv", "./data/cmds_sequence_2016-07-26.csv", "./data/cmds_sequence_2016-07-27.csv", "./data/cmds_sequence_2016-07-28.csv", 
    "./data/cmds_sequence_2016-07-29.csv", "./data/cmds_sequence_2016-07-30.csv", "./data/cmds_sequence_2016-07-31.csv", "./data/cmds_sequence_2016-08-29.csv", 
    "./data/cmds_sequence_2016-08-30.csv", "./data/cmds_sequence_2016-08-31.csv", "./data/cmds_sequence_2016-09-01.csv", "./data/cmds_sequence_2016-09-02.csv", 
    "./data/cmds_sequence_2016-09-03.csv", "./data/cmds_sequence_2016-09-04.csv", "./data/cmds_sequence_2016-09-05.csv", "./data/cmds_sequence_2016-09-06.csv", 
    "./data/cmds_sequence_2016-09-07.csv", "./data/cmds_sequence_2016-09-08.csv", "./data/cmds_sequence_2016-09-09.csv", "./data/cmds_sequence_2016-09-10.csv", 
    "./data/cmds_sequence_2016-09-11.csv", "./data/cmds_sequence_2016-09-12.csv", "./data/cmds_sequence_2016-09-13.csv"
]

def read_data(path):
    return pd.read_csv(path, 
                   sep="\$\$",
                   header=None, 
                   names=["Timestamp", "Src IP", "Src Port", "Dest IP", "Dest Port", "Commandlist"], 
                   index_col=False)

def login_attempts(data):
    return len(data)

def top_5_dest_ip(data):
    return data["Dest IP"].value_counts().head(5)

def top_5_dest_port(data):
    return data["Dest Port"].value_counts().head(5)

def top_5_src_ip(data):
    return data["Src IP"].value_counts().head(5)

def top_5_src_port(data):
    return data["Src Port"].value_counts().head(5)

# %%
data = read_data(files[0])
print("Login attempts", login_attempts(data))
print("Top 5 src IPs\n", top_5_src_ip(data))
print("Top 5 src ports\n", top_5_src_port(data))
print("Top 5 dest IPs\n", top_5_dest_ip(data))
print("Top 5 dest ports\n", top_5_dest_port(data))
# Out:
# /home/jupyter/venv/lib/python3.7/site-packages/ipykernel_launcher.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# Login attempts 54857
# Top 5 src IPs
#  115.177.11.215    18825
# 91.234.124.23       129
# 61.32.10.101        129
# 91.103.29.251       129
# 182.180.84.89       129
# Name: Src IP, dtype: int64
# Top 5 src ports
#  41089    8
# 40918    8
# 44330    7
# 35241    7
# 33443    7
# Name: Src Port, dtype: int64
# Top 5 dest IPs
#  133.34.157.181    19071
# 133.34.157.178      345
# 133.34.157.180      341
# 133.34.157.92       341
# 133.34.157.161      336
# Name: Dest IP, dtype: int64
# Top 5 dest ports
#  23    54857
# Name: Dest Port, dtype: int64

# %%
ys = []
for f in files:
    print("Reading file:", f)
    data = read_data(f)
    ys.append(login_attempts(data))
    print("Login attempts", ys[-1])
#     print("Top 5 src IPs", top_5_src_ip(data))
#     print("Top 5 src ports", top_5_src_port(data))
#     print("Top 5 dest IPs", top_5_dest_ip(data))
#     print("Top 5 dest ports", top_5_dest_port(data))
# Out:
# Reading file: ./data/cmds_sequence_2016-07-01.csv
# /home/jupyter/venv/lib/python3.7/site-packages/ipykernel_launcher.py:20: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# Login attempts 54857
# Reading file: ./data/cmds_sequence_2016-07-02.csv
# Login attempts 56912
# Reading file: ./data/cmds_sequence_2016-07-03.csv
# Login attempts 54880
# Reading file: ./data/cmds_sequence_2016-07-04.csv
# Login attempts 57246
# Reading file: ./data/cmds_sequence_2016-07-05.csv
# Login attempts 57368
# Reading file: ./data/cmds_sequence_2016-07-06.csv
# Login attempts 46448
# Reading file: ./data/cmds_sequence_2016-07-07.csv
# Login attempts 56270
# Reading file: ./data/cmds_sequence_2016-07-08.csv
# Login attempts 50532
# Reading file: ./data/cmds_sequence_2016-07-09.csv
# Login attempts 44118
# Reading file: ./data/cmds_sequence_2016-07-10.csv
# Login attempts 43814
# Reading file: ./data/cmds_sequence_2016-07-11.csv
# Login attempts 43012
# Reading file: ./data/cmds_sequence_2016-07-12.csv
# Login attempts 47779
# Reading file: ./data/cmds_sequence_2016-07-13.csv
# Login attempts 54658
# Reading file: ./data/cmds_sequence_2016-07-14.csv
# Login attempts 44681
# Reading file: ./data/cmds_sequence_2016-07-15.csv
# Login attempts 50533
# Reading file: ./data/cmds_sequence_2016-07-16.csv
# Login attempts 46947
# Reading file: ./data/cmds_sequence_2016-07-17.csv
# Login attempts 66422
# Reading file: ./data/cmds_sequence_2016-07-18.csv
# Login attempts 70585
# Reading file: ./data/cmds_sequence_2016-07-19.csv
# Login attempts 45280
# Reading file: ./data/cmds_sequence_2016-07-20.csv
# Login attempts 40130
# Reading file: ./data/cmds_sequence_2016-07-21.csv
# Login attempts 50804
# Reading file: ./data/cmds_sequence_2016-07-22.csv
# Login attempts 58610
# Reading file: ./data/cmds_sequence_2016-07-23.csv
# Login attempts 51826
# Reading file: ./data/cmds_sequence_2016-07-24.csv
# Login attempts 58138
# Reading file: ./data/cmds_sequence_2016-07-25.csv
# Login attempts 56768
# Reading file: ./data/cmds_sequence_2016-07-26.csv
# Login attempts 51868
# Reading file: ./data/cmds_sequence_2016-07-27.csv
# Login attempts 48562
# Reading file: ./data/cmds_sequence_2016-07-28.csv
# Login attempts 21674
# Reading file: ./data/cmds_sequence_2016-07-29.csv
# Login attempts 46606
# Reading file: ./data/cmds_sequence_2016-07-30.csv
# Login attempts 17249
# Reading file: ./data/cmds_sequence_2016-07-31.csv
# Login attempts 22850
# Reading file: ./data/cmds_sequence_2016-08-29.csv
# Login attempts 261111
# Reading file: ./data/cmds_sequence_2016-08-30.csv
# Login attempts 264752
# Reading file: ./data/cmds_sequence_2016-08-31.csv
# Login attempts 192925
# Reading file: ./data/cmds_sequence_2016-09-01.csv
# Login attempts 236406
# Reading file: ./data/cmds_sequence_2016-09-02.csv
# Login attempts 185742
# Reading file: ./data/cmds_sequence_2016-09-03.csv
# Login attempts 81411
# Reading file: ./data/cmds_sequence_2016-09-04.csv
# Login attempts 184349
# Reading file: ./data/cmds_sequence_2016-09-05.csv
# Login attempts 81411
# Reading file: ./data/cmds_sequence_2016-09-06.csv
# Login attempts 57161
# Reading file: ./data/cmds_sequence_2016-09-07.csv
# Login attempts 50804
# Reading file: ./data/cmds_sequence_2016-09-08.csv
# Login attempts 64313
# Reading file: ./data/cmds_sequence_2016-09-09.csv
# Login attempts 81411
# Reading file: ./data/cmds_sequence_2016-09-10.csv
# Login attempts 64313
# Reading file: ./data/cmds_sequence_2016-09-11.csv
# Login attempts 5192
# Reading file: ./data/cmds_sequence_2016-09-12.csv
# Login attempts 45153
# Reading file: ./data/cmds_sequence_2016-09-13.csv
# Login attempts 40130

# %%
xs = np.arange(0, len(ys))
plt.ylabel("Login attempt")
plt.xlabel("Day")
plt.title("Login attempts per day")
plt.tight_layout()
plt.plot(xs, ys)
plt.savefig("plot.png", dpi=400)

# %% [markdown]
# Reading file: ./data/cmds_sequence_2016-07-01.csv
#
# /home/jupyter/venv/lib/python3.7/site-packages/ipykernel_launcher.py:17: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# Login attempts 54857
# Reading file: ./data/cmds_sequence_2016-07-11.csv
# Login attempts 43012
# Reading file: ./data/cmds_sequence_2016-07-21.csv
# Login attempts 50804
# Reading file: ./data/cmds_sequence_2016-07-31.csv
# Login attempts 22850
# Reading file: ./data/cmds_sequence_2016-09-07.csv
# Login attempts 50804
# Reading file: ./data/cmds_sequence_2016-07-02.csv
# Login attempts 56912
# Reading file: ./data/cmds_sequence_2016-07-12.csv
# Login attempts 47779
# Reading file: ./data/cmds_sequence_2016-07-22.csv
# Login attempts 58610
# Reading file: ./data/cmds_sequence_2016-08-29.csv
# Login attempts 261111
# Reading file: ./data/cmds_sequence_2016-09-08.csv
# Login attempts 64313
# Reading file: ./data/cmds_sequence_2016-07-03.csv
# Login attempts 54880
# Reading file: ./data/cmds_sequence_2016-07-13.csv
# Login attempts 54658
# Reading file: ./data/cmds_sequence_2016-07-23.csv
# Login attempts 51826
# Reading file: ./data/cmds_sequence_2016-08-30.csv
# Login attempts 264752
# Reading file: ./data/cmds_sequence_2016-09-09.csv
# Login attempts 81411
# Reading file: ./data/cmds_sequence_2016-07-04.csv
# Login attempts 57246
# Reading file: ./data/cmds_sequence_2016-07-14.csv
# Login attempts 44681
# Reading file: ./data/cmds_sequence_2016-07-24.csv
# Login attempts 58138
# Reading file: ./data/cmds_sequence_2016-08-31.csv
# Login attempts 192925
# Reading file: ./data/cmds_sequence_2016-09-10.csv
# Login attempts 64313
# Reading file: ./data/cmds_sequence_2016-07-05.csv
# Login attempts 57368
# Reading file: ./data/cmds_sequence_2016-07-15.csv
# Login attempts 50533
# Reading file: ./data/cmds_sequence_2016-07-25.csv
# Login attempts 56768
# Reading file: ./data/cmds_sequence_2016-09-01.csv
# Login attempts 236406
# Reading file: ./data/cmds_sequence_2016-09-11.csv
# Login attempts 5192
# Reading file: ./data/cmds_sequence_2016-07-06.csv
# Login attempts 46448
# Reading file: ./data/cmds_sequence_2016-07-16.csv
# Login attempts 46947
# Reading file: ./data/cmds_sequence_2016-07-26.csv
# Login attempts 51868
# Reading file: ./data/cmds_sequence_2016-09-02.csv
# Login attempts 185742
# Reading file: ./data/cmds_sequence_2016-09-12.csv
# Login attempts 45153
# Reading file: ./data/cmds_sequence_2016-07-07.csv
# Login attempts 56270
# Reading file: ./data/cmds_sequence_2016-07-17.csv
# Login attempts 66422
# Reading file: ./data/cmds_sequence_2016-07-27.csv
# Login attempts 48562
# Reading file: ./data/cmds_sequence_2016-09-03.csv
# Login attempts 81411
# Reading file: ./data/cmds_sequence_2016-09-13.csv
# Login attempts 40130
# Reading file: ./data/cmds_sequence_2016-07-08.csv
# Login attempts 50532
# Reading file: ./data/cmds_sequence_2016-07-18.csv
# Login attempts 70585
# Reading file: ./data/cmds_sequence_2016-07-28.csv
# Login attempts 21674
# Reading file: ./data/cmds_sequence_2016-09-04.csv
# Login attempts 184349
# Reading file: ./data/cmds_sequence_2016-07-09.csv
# Login attempts 44118
# Reading file: ./data/cmds_sequence_2016-07-19.csv
# Login attempts 45280
# Reading file: ./data/cmds_sequence_2016-07-29.csv
# Login attempts 46606
# Reading file: ./data/cmds_sequence_2016-09-05.csv
# Login attempts 81411
# Reading file: ./data/cmds_sequence_2016-07-10.csv
# Login attempts 43814
# Reading file: ./data/cmds_sequence_2016-07-20.csv
# Login attempts 40130
# Reading file: ./data/cmds_sequence_2016-07-30.csv
# Login attempts 17249
# Reading file: ./data/cmds_sequence_2016-09-06.csv
# Login attempts 57161
